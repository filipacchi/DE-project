# %%
import pyspark
from pyspark.sql import SparkSession, Row
from pyspark.sql.types import StructType, StructField, DoubleType, StringType, IntegerType, FloatType
from pyspark.sql.functions import col
import h5py

# %%
# Spark session build
spark_session = SparkSession\
        .builder\
        .master("spark://192.168.2.130:7077") \
        .appName("de16_sparky_read_h5_to_csv")\
        .config("spark.dynamicAllocation.enabled", True)\
        .config("spark.dynamicAllocation.shuffleTracking.enabled",True)\
        .config("spark.shuffle.service.enabled", False)\
        .config("spark.dynamicAllocation.executorIdleTimeout","300s")\
        .config("spark.executor.cores",2)\
        .config("spark.driver.port",9999)\
        .config("spark.blockManager.port",10005)\
        .config("spark.hadoop.fs.defaultFS", "hdfs://192.168.2.130:9000")\
        .getOrCreate()

sc = spark_session.sparkContext
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/03/07 19:37:55 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
# Structure of the final DataFrame
columns = StructType([
    StructField('artist_name', StringType(), nullable=True),
    StructField('danceability', DoubleType(), nullable=True),
    StructField('duration', DoubleType(), nullable=True),
    StructField('end_of_fade_in', DoubleType(), nullable=True),
    StructField('energy', DoubleType(), nullable=True),
    StructField('key', IntegerType(), nullable=True),
    StructField('key_confidence', DoubleType(), nullable=True),
    StructField('loudness', DoubleType(), nullable=True),
    StructField('mode', IntegerType(), nullable=True),
    StructField('mode_confidence', DoubleType(), nullable=True),
    StructField('release', StringType(), nullable=True),
    StructField('song_hotttnesss', DoubleType(), nullable=True),
    StructField('song_id', StringType(), nullable=True),
    StructField('start_of_fade_out', DoubleType(), nullable=True),
    StructField('tempo', DoubleType(), nullable=True),
    StructField('time_signature', IntegerType(), nullable=True),
    StructField('time_signature_confidence', DoubleType(), nullable=True),
    StructField('title', StringType(), nullable=True),
    StructField('year', IntegerType(), nullable=True)
])

# %%
import io

# Read relevant content of h5 file
def read_h5_content(path):
    binary = spark_session.read.format("binaryFile").load(path)
    content = io.BytesIO(binary.first()['content'])
    with h5py.File(content, 'r') as file:
        data = {
            'artist_name': str(file['metadata']['songs'][0][9])[2:-1],
            'danceability': float(file['analysis']['songs'][0][2]),
            'duration': float(file['analysis']['songs'][0][3]),
            'end_of_fade_in': float(file['analysis']['songs'][0][4]),
            'energy': float(file['analysis']['songs'][0][5]),
            'key': int(file['analysis']['songs'][0][21]),
            'key_confidence': float(file['analysis']['songs'][0][22]),
            'loudness': float(file['analysis']['songs'][0][23]),
            'mode': int(file['analysis']['songs'][0][24]),
            'mode_confidence': float(file['analysis']['songs'][0][25]),
            'release': str(file['metadata']['songs'][0][14])[2:-1],
            'song_hotttnesss': float(file['metadata']['songs'][0][16]),
            'song_id': str(file['metadata']['songs'][0][17])[2:-1],
            'start_of_fade_out': float(file['analysis']['songs'][0][26]),
            'tempo': float(file['analysis']['songs'][0][27]),
            'time_signature': int(file['analysis']['songs'][0][28]),
            'time_signature_confidence': float(file['analysis']['songs'][0][29]),
            'title': str(file['metadata']['songs'][0][18])[2:-1],
            'year': int(file['musicbrainz']['songs'][0][1])
        }
    return data

# %%
import time

# Get paths to all h5 files in the data set
def list_h5_files(path):
    hadoop_conf = sc._jsc.hadoopConfiguration()
    fs = sc._jvm.org.apache.hadoop.fs.FileSystem.get(hadoop_conf)
    files = []
    status = fs.listStatus(sc._jvm.org.apache.hadoop.fs.Path(path))
    for file_status in status:
        file_path = file_status.getPath()
        if file_status.isDirectory():
            files.extend(list_h5_files(file_path.toString()))
        elif file_path.toString().endswith(".h5"):
            files.append(file_path.toString())
    return files

base_directory = "hdfs://192.168.2.130:9000/user/MillionSongSubset"
start_time = time.time()

print('Getting paths...')
song_paths = list_h5_files(base_directory)

print('Extracting data...')
extracted_data = [read_h5_content(path) for path in song_paths]

print('Converting to rows...')
rows = [Row(**data) for data in extracted_data]

print('Converting to DataFrame')
df = spark_session.createDataFrame(rows, schema=columns)
print(f'Time spent reading data: {time.time()-start_time}')

# Display DataFrame to verify
df.show()
df.printSchema()
print(df.count())
print(df.rdd.getNumPartitions())

# Write DataFrame to csv on HDFS
df.write.mode("overwrite").csv("hdfs://192.168.2.130:9000/user/MillionSongSubset.csv")
# Out:
# Getting paths...
# Extracting data...
# Converting to rows...
# Converting to DataFrame
# Time spent reading data: 1030.6085057258606
# +--------------------+------------+---------+--------------+------+---+--------------+--------+----+---------------+--------------------+-------------------+------------------+-----------------+-------+--------------+-------------------------+--------------------+----+
# |         artist_name|danceability| duration|end_of_fade_in|energy|key|key_confidence|loudness|mode|mode_confidence|             release|    song_hotttnesss|           song_id|start_of_fade_out|  tempo|time_signature|time_signature_confidence|               title|year|
# +--------------------+------------+---------+--------------+------+---+--------------+--------+----+---------------+--------------------+-------------------+------------------+-----------------+-------+--------------+-------------------------+--------------------+----+
# |              Casual|         0.0|218.93179|         0.247|   0.0|  1|         0.736| -11.197|   0|          0.636|         Fear Itself| 0.6021199899057548|SOMZWCG12A8C13C480|          218.932| 92.198|             4|                    0.778|    I Didn't Mean To|   0|
# |        The Box Tops|         0.0|148.03546|         0.148|   0.0|  6|         0.169|  -9.843|   0|           0.43|          Dimensions|                NaN|SOCIWDW12A8C13D406|          137.915|121.274|             4|                    0.384|           Soul Deep|1969|
# |    Sonora Santanera|         0.0|177.47546|         0.282|   0.0|  8|         0.643|  -9.689|   1|          0.565|Las Numero 1 De L...|                NaN|SOXVLOJ12AB0189215|          172.304| 100.07|             1|                      0.0|     Amor De Cabaret|   0|
# |            Adam Ant|         0.0|233.40363|           0.0|   0.0|  0|         0.751|  -9.013|   1|          0.749|       Friend Or Foe|                NaN|SONHOTT12A8C13493C|          217.124|119.293|             4|                      0.0|     Something Girls|1982|
# |                 Gob|         0.0|209.60608|         0.066|   0.0|  2|         0.092|  -4.501|   1|          0.371|       Muertos Vivos| 0.6045007385888197|SOFSOCN12A8C143F5D|          198.699|129.738|             4|                    0.562|      Face the Ashes|2007|
# |Jeff And Sheri Ea...|         0.0| 267.7024|         2.264|   0.0|  5|         0.635|  -9.323|   1|          0.557|        Ordinary Day|                NaN|SOYMRWW12A6D4FAB14|           254.27|147.782|             3|                    0.454|The Moon And I (O...|   0|
# |             Rated R|         0.0|114.78159|         0.096|   0.0|  1|           0.0| -17.302|   1|            0.0|   Da Ghetto Psychic|                NaN|SOMJBYD12A6D4F8557|          114.782|111.787|             1|                      0.0|Keepin It Real (S...|   0|
# |Tweeterfriendly M...|         0.0|189.57016|         0.319|   0.0|  4|           0.0| -11.642|   0|           0.16|        Gin & Phonic|                NaN|SOHKNRJ12A6701D1F8|          181.023| 101.43|             3|                    0.408|        Drop of Rain|   0|
# |    Planet P Project|         0.0|269.81832|           5.3|   0.0|  4|         0.717| -13.496|   1|          0.652|          Pink World|0.26586104921065007|SOIAZJW12AB01853F1|           258.99| 86.643|             4|                    0.487|          Pink World|1984|
# |                 Clp|         0.0|266.39628|         0.084|   0.0|  7|         0.053|  -6.697|   0|          0.473|   Superinstrumental|                NaN|SOUDSGM12AC9618304|          261.747|114.041|             4|                    0.878|Insatiable (Instr...|   0|
# |        JennyAnyKind|         0.0|218.77506|         2.125|   0.0|  5|         0.354| -10.021|   0|          0.485|          I Need You|                0.0|SOQHXMF12AB0182363|          207.012|146.765|             1|                      0.0|     Young Boy Blues|   0|
# |        Wayne Watson|         0.0|245.21098|         0.357|   0.0|  7|          0.07|  -7.545|   1|          0.686|        The Way Home|0.26586104921065007|SOKEJEJ12A8C13E0D0|           227.48|117.975|             4|                    0.835|The Urgency (LP V...|   0|
# |           Andy Andy|         0.0|226.35057|           0.0|   0.0|  9|         0.205|  -6.632|   1|          0.305|    Placer & Castigo|                0.0|SOMUYGI12AB0188633|          221.553| 130.04|             4|                      0.0|            La Culpa|   0|
# |           Bob Azzam|         0.0|191.84281|          0.38|   0.0| 10|           0.0|   -7.75|   0|          0.198|         Arrivederci|                0.0|SORAMLE12AB017C8B0|          188.424|137.334|             1|                    0.319|      Auguri Cha Cha|   0|
# |       Lionel Richie|         0.0| 307.3824|         0.612|   0.0|  3|         0.524|  -8.346|   1|          0.533|Dancing On The Ce...|                NaN|SOBONFF12A6D4F84D8|          296.658|125.197|             3|                    0.211|Tonight Will Be A...|1986|
# |          Blue Rodeo|         0.0|491.12771|           0.0|   0.0|  7|           1.0|  -8.576|   1|          0.829|           Outskirts| 0.4051157216913865|SOHUOAP12A8AE488E9|          486.034|119.826|             4|                    0.756|            Floating|1987|
# |     Richard Souther|         0.0| 228.5971|         0.223|   0.0|  8|         0.041|  -16.11|   1|          0.516|      Cross Currents| 0.3347065490692206|SOUQQEA12A8C134B1B|          217.426|127.756|             5|                    0.579|           High Tide|   0|
# |       Faiz Ali Faiz|         0.0|599.24853|         1.193|   0.0|  6|          0.06|  -8.032|   1|          0.346|   Panjtan Ka Ghulam|                NaN|SOILPQQ12AB017E82A|          591.999| 99.273|             4|                    0.158|Sohna Nee Sohna Data|   0|
# |               Tesla|         0.0|290.29832|         0.145|   0.0|  7|         0.725|  -5.271|   1|          0.756|                Gold| 0.6841361912294903|SOXLBJT12A8C140925|          285.605|150.062|             4|                    0.931|   Caught In A Dream|2004|
# |           lextrical|         0.0|165.69424|         0.162|   0.0|  7|         0.011|  -6.787|   1|          0.568|Whatever Happened...|                0.0|SOZVMJI12AB01808AF|          157.391|138.331|             4|                    0.127|     Synthetic Dream|   0|
# +--------------------+------------+---------+--------------+------+---+--------------+--------+----+---------------+--------------------+-------------------+------------------+-----------------+-------+--------------+-------------------------+--------------------+----+
# only showing top 20 rows
#
# root
#  |-- artist_name: string (nullable = true)
#  |-- danceability: double (nullable = true)
#  |-- duration: double (nullable = true)
#  |-- end_of_fade_in: double (nullable = true)
#  |-- energy: double (nullable = true)
#  |-- key: integer (nullable = true)
#  |-- key_confidence: double (nullable = true)
#  |-- loudness: double (nullable = true)
#  |-- mode: integer (nullable = true)
#  |-- mode_confidence: double (nullable = true)
#  |-- release: string (nullable = true)
#  |-- song_hotttnesss: double (nullable = true)
#  |-- song_id: string (nullable = true)
#  |-- start_of_fade_out: double (nullable = true)
#  |-- tempo: double (nullable = true)
#  |-- time_signature: integer (nullable = true)
#  |-- time_signature_confidence: double (nullable = true)
#  |-- title: string (nullable = true)
#  |-- year: integer (nullable = true)
#
# 10000
# 2
# 24/03/07 20:37:58 ERROR TransportResponseHandler: Still have 1 requests outstanding when connection from /192.168.2.142:51656 is closed
# 24/03/07 20:37:58 WARN BlockManagerMasterEndpoint: Error trying to remove broadcast 39365 from block manager BlockManagerId(0, 192.168.2.142, 10005, None)
# java.io.IOException: Connection from /192.168.2.142:51656 closed
# 	at org.apache.spark.network.client.TransportResponseHandler.channelInactive(TransportResponseHandler.java:147)
# 	at org.apache.spark.network.server.TransportChannelHandler.channelInactive(TransportChannelHandler.java:117)
# 	at io.netty.channel.AbstractChannelHandlerContext.invokeChannelInactive(AbstractChannelHandlerContext.java:305)
# 	at io.netty.channel.AbstractChannelHandlerContext.invokeChannelInactive(AbstractChannelHandlerContext.java:281)
# 	at io.netty.channel.AbstractChannelHandlerContext.fireChannelInactive(AbstractChannelHandlerContext.java:274)
# 	at io.netty.channel.ChannelInboundHandlerAdapter.channelInactive(ChannelInboundHandlerAdapter.java:81)
# 	at io.netty.handler.timeout.IdleStateHandler.channelInactive(IdleStateHandler.java:277)
# 	at io.netty.channel.AbstractChannelHandlerContext.invokeChannelInactive(AbstractChannelHandlerContext.java:303)
# 	at io.netty.channel.AbstractChannelHandlerContext.invokeChannelInactive(AbstractChannelHandlerContext.java:281)
# 	at io.netty.channel.AbstractChannelHandlerContext.fireChannelInactive(AbstractChannelHandlerContext.java:274)
# 	at io.netty.channel.ChannelInboundHandlerAdapter.channelInactive(ChannelInboundHandlerAdapter.java:81)
# 	at org.apache.spark.network.util.TransportFrameDecoder.channelInactive(TransportFrameDecoder.java:225)
# 	at io.netty.channel.AbstractChannelHandlerContext.invokeChannelInactive(AbstractChannelHandlerContext.java:305)
# 	at io.netty.channel.AbstractChannelHandlerContext.invokeChannelInactive(AbstractChannelHandlerContext.java:281)
# 	at io.netty.channel.AbstractChannelHandlerContext.fireChannelInactive(AbstractChannelHandlerContext.java:274)
# 	at io.netty.channel.DefaultChannelPipeline$HeadContext.channelInactive(DefaultChannelPipeline.java:1405)
# 	at io.netty.channel.AbstractChannelHandlerContext.invokeChannelInactive(AbstractChannelHandlerContext.java:301)
# 	at io.netty.channel.AbstractChannelHandlerContext.invokeChannelInactive(AbstractChannelHandlerContext.java:281)
# 	at io.netty.channel.DefaultChannelPipeline.fireChannelInactive(DefaultChannelPipeline.java:901)
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe$7.run(AbstractChannel.java:813)
# 	at io.netty.util.concurrent.AbstractEventExecutor.runTask(AbstractEventExecutor.java:174)
# 	at io.netty.util.concurrent.AbstractEventExecutor.safeExecute(AbstractEventExecutor.java:167)
# 	at io.netty.util.concurrent.SingleThreadEventExecutor.runAllTasks(SingleThreadEventExecutor.java:470)
# 	at io.netty.channel.nio.NioEventLoop.run(NioEventLoop.java:566)
# 	at io.netty.util.concurrent.SingleThreadEventExecutor$4.run(SingleThreadEventExecutor.java:997)
# 	at io.netty.util.internal.ThreadExecutorMap$2.run(ThreadExecutorMap.java:74)
# 	at io.netty.util.concurrent.FastThreadLocalRunnable.run(FastThreadLocalRunnable.java:30)
# 	at java.lang.Thread.run(Thread.java:750)
# 24/03/07 20:37:58 ERROR TransportClient: Failed to send RPC RPC 5472672213627965444 to /192.168.2.142:51656: io.netty.channel.StacklessClosedChannelException
# io.netty.channel.StacklessClosedChannelException
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe.write(Object, ChannelPromise)(Unknown Source)
# 24/03/07 20:37:58 WARN BlockManagerMasterEndpoint: Error trying to remove broadcast 39447 from block manager BlockManagerId(0, 192.168.2.142, 10005, None)
# java.io.IOException: Failed to send RPC RPC 5472672213627965444 to /192.168.2.142:51656: io.netty.channel.StacklessClosedChannelException
# 	at org.apache.spark.network.client.TransportClient$RpcChannelListener.handleFailure(TransportClient.java:395)
# 	at org.apache.spark.network.client.TransportClient$StdChannelListener.operationComplete(TransportClient.java:372)
# 	at io.netty.util.concurrent.DefaultPromise.notifyListener0(DefaultPromise.java:590)
# 	at io.netty.util.concurrent.DefaultPromise.notifyListenersNow(DefaultPromise.java:557)
# 	at io.netty.util.concurrent.DefaultPromise.notifyListeners(DefaultPromise.java:492)
# 	at io.netty.util.concurrent.DefaultPromise.setValue0(DefaultPromise.java:636)
# 	at io.netty.util.concurrent.DefaultPromise.setFailure0(DefaultPromise.java:629)
# 	at io.netty.util.concurrent.DefaultPromise.tryFailure(DefaultPromise.java:118)
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe.safeSetFailure(AbstractChannel.java:999)
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe.write(AbstractChannel.java:860)
# 	at io.netty.channel.DefaultChannelPipeline$HeadContext.write(DefaultChannelPipeline.java:1367)
# 	at io.netty.channel.AbstractChannelHandlerContext.invokeWrite0(AbstractChannelHandlerContext.java:877)
# 	at io.netty.channel.AbstractChannelHandlerContext.invokeWriteAndFlush(AbstractChannelHandlerContext.java:940)
# 	at io.netty.channel.AbstractChannelHandlerContext$WriteTask.run(AbstractChannelHandlerContext.java:1247)
# 	at io.netty.util.concurrent.AbstractEventExecutor.runTask(AbstractEventExecutor.java:174)
# 	at io.netty.util.concurrent.AbstractEventExecutor.safeExecute(AbstractEventExecutor.java:167)
# 	at io.netty.util.concurrent.SingleThreadEventExecutor.runAllTasks(SingleThreadEventExecutor.java:470)
# 	at io.netty.channel.nio.NioEventLoop.run(NioEventLoop.java:569)
# 	at io.netty.util.concurrent.SingleThreadEventExecutor$4.run(SingleThreadEventExecutor.java:997)
# 	at io.netty.util.internal.ThreadExecutorMap$2.run(ThreadExecutorMap.java:74)
# 	at io.netty.util.concurrent.FastThreadLocalRunnable.run(FastThreadLocalRunnable.java:30)
# 	at java.lang.Thread.run(Thread.java:750)
# Caused by: io.netty.channel.StacklessClosedChannelException
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe.write(Object, ChannelPromise)(Unknown Source)
# 24/03/07 20:37:58 ERROR TransportClient: Failed to send RPC RPC 6784013949491851315 to /192.168.2.142:51656: io.netty.channel.StacklessClosedChannelException
# io.netty.channel.StacklessClosedChannelException
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe.write(Object, ChannelPromise)(Unknown Source)
# 24/03/07 20:37:58 WARN BlockManagerMasterEndpoint: Error trying to remove broadcast 39127 from block manager BlockManagerId(0, 192.168.2.142, 10005, None)
# java.io.IOException: Failed to send RPC RPC 6784013949491851315 to /192.168.2.142:51656: io.netty.channel.StacklessClosedChannelException
# 	at org.apache.spark.network.client.TransportClient$RpcChannelListener.handleFailure(TransportClient.java:395)
# 	at org.apache.spark.network.client.TransportClient$StdChannelListener.operationComplete(TransportClient.java:372)
# 	at io.netty.util.concurrent.DefaultPromise.notifyListener0(DefaultPromise.java:590)
# 	at io.netty.util.concurrent.DefaultPromise.notifyListenersNow(DefaultPromise.java:557)
# 	at io.netty.util.concurrent.DefaultPromise.notifyListeners(DefaultPromise.java:492)
# 	at io.netty.util.concurrent.DefaultPromise.setValue0(DefaultPromise.java:636)
# 	at io.netty.util.concurrent.DefaultPromise.setFailure0(DefaultPromise.java:629)
# 	at io.netty.util.concurrent.DefaultPromise.tryFailure(DefaultPromise.java:118)
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe.safeSetFailure(AbstractChannel.java:999)
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe.write(AbstractChannel.java:860)
# 	at io.netty.channel.DefaultChannelPipeline$HeadContext.write(DefaultChannelPipeline.java:1367)
# 	at io.netty.channel.AbstractChannelHandlerContext.invokeWrite0(AbstractChannelHandlerContext.java:877)
# 	at io.netty.channel.AbstractChannelHandlerContext.invokeWriteAndFlush(AbstractChannelHandlerContext.java:940)
# 	at io.netty.channel.AbstractChannelHandlerContext$WriteTask.run(AbstractChannelHandlerContext.java:1247)
# 	at io.netty.util.concurrent.AbstractEventExecutor.runTask(AbstractEventExecutor.java:174)
# 	at io.netty.util.concurrent.AbstractEventExecutor.safeExecute(AbstractEventExecutor.java:167)
# 	at io.netty.util.concurrent.SingleThreadEventExecutor.runAllTasks(SingleThreadEventExecutor.java:470)
# 	at io.netty.channel.nio.NioEventLoop.run(NioEventLoop.java:569)
# 	at io.netty.util.concurrent.SingleThreadEventExecutor$4.run(SingleThreadEventExecutor.java:997)
# 	at io.netty.util.internal.ThreadExecutorMap$2.run(ThreadExecutorMap.java:74)
# 	at io.netty.util.concurrent.FastThreadLocalRunnable.run(FastThreadLocalRunnable.java:30)
# 	at java.lang.Thread.run(Thread.java:750)
# Caused by: io.netty.channel.StacklessClosedChannelException
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe.write(Object, ChannelPromise)(Unknown Source)
# 24/03/07 20:37:58 ERROR TransportClient: Failed to send RPC RPC 9073820291687379273 to /192.168.2.142:51656: io.netty.channel.StacklessClosedChannelException
# io.netty.channel.StacklessClosedChannelException
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe.write(Object, ChannelPromise)(Unknown Source)
# 24/03/07 20:37:58 WARN BlockManagerMasterEndpoint: Error trying to remove broadcast 38725 from block manager BlockManagerId(0, 192.168.2.142, 10005, None)
# java.io.IOException: Failed to send RPC RPC 9073820291687379273 to /192.168.2.142:51656: io.netty.channel.StacklessClosedChannelException
# 	at org.apache.spark.network.client.TransportClient$RpcChannelListener.handleFailure(TransportClient.java:395)
# 	at org.apache.spark.network.client.TransportClient$StdChannelListener.operationComplete(TransportClient.java:372)
# 	at io.netty.util.concurrent.DefaultPromise.notifyListener0(DefaultPromise.java:590)
# 	at io.netty.util.concurrent.DefaultPromise.notifyListenersNow(DefaultPromise.java:557)
# 	at io.netty.util.concurrent.DefaultPromise.notifyListeners(DefaultPromise.java:492)
# 	at io.netty.util.concurrent.DefaultPromise.setValue0(DefaultPromise.java:636)
# 	at io.netty.util.concurrent.DefaultPromise.setFailure0(DefaultPromise.java:629)
# 	at io.netty.util.concurrent.DefaultPromise.tryFailure(DefaultPromise.java:118)
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe.safeSetFailure(AbstractChannel.java:999)
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe.write(AbstractChannel.java:860)
# 	at io.netty.channel.DefaultChannelPipeline$HeadContext.write(DefaultChannelPipeline.java:1367)
# 	at io.netty.channel.AbstractChannelHandlerContext.invokeWrite0(AbstractChannelHandlerContext.java:877)
# 	at io.netty.channel.AbstractChannelHandlerContext.invokeWriteAndFlush(AbstractChannelHandlerContext.java:940)
# 	at io.netty.channel.AbstractChannelHandlerContext$WriteTask.run(AbstractChannelHandlerContext.java:1247)
# 	at io.netty.util.concurrent.AbstractEventExecutor.runTask(AbstractEventExecutor.java:174)
# 	at io.netty.util.concurrent.AbstractEventExecutor.safeExecute(AbstractEventExecutor.java:167)
# 	at io.netty.util.concurrent.SingleThreadEventExecutor.runAllTasks(SingleThreadEventExecutor.java:470)
# 	at io.netty.channel.nio.NioEventLoop.run(NioEventLoop.java:569)
# 	at io.netty.util.concurrent.SingleThreadEventExecutor$4.run(SingleThreadEventExecutor.java:997)
# 	at io.netty.util.internal.ThreadExecutorMap$2.run(ThreadExecutorMap.java:74)
# 	at io.netty.util.concurrent.FastThreadLocalRunnable.run(FastThreadLocalRunnable.java:30)
# 	at java.lang.Thread.run(Thread.java:750)
# Caused by: io.netty.channel.StacklessClosedChannelException
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe.write(Object, ChannelPromise)(Unknown Source)
# 24/03/07 20:37:58 ERROR TransportClient: Failed to send RPC RPC 7645518881860744644 to /192.168.2.142:51656: io.netty.channel.StacklessClosedChannelException
# io.netty.channel.StacklessClosedChannelException
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe.write(Object, ChannelPromise)(Unknown Source)
# 24/03/07 20:37:58 WARN BlockManagerMasterEndpoint: Error trying to remove broadcast 39633 from block manager BlockManagerId(0, 192.168.2.142, 10005, None)
# java.io.IOException: Failed to send RPC RPC 7645518881860744644 to /192.168.2.142:51656: io.netty.channel.StacklessClosedChannelException
# 	at org.apache.spark.network.client.TransportClient$RpcChannelListener.handleFailure(TransportClient.java:395)
# 	at org.apache.spark.network.client.TransportClient$StdChannelListener.operationComplete(TransportClient.java:372)
# 	at io.netty.util.concurrent.DefaultPromise.notifyListener0(DefaultPromise.java:590)
# 	at io.netty.util.concurrent.DefaultPromise.notifyListenersNow(DefaultPromise.java:557)
# 	at io.netty.util.concurrent.DefaultPromise.notifyListeners(DefaultPromise.java:492)
# 	at io.netty.util.concurrent.DefaultPromise.setValue0(DefaultPromise.java:636)
# 	at io.netty.util.concurrent.DefaultPromise.setFailure0(DefaultPromise.java:629)
# 	at io.netty.util.concurrent.DefaultPromise.tryFailure(DefaultPromise.java:118)
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe.safeSetFailure(AbstractChannel.java:999)
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe.write(AbstractChannel.java:860)
# 	at io.netty.channel.DefaultChannelPipeline$HeadContext.write(DefaultChannelPipeline.java:1367)
# 	at io.netty.channel.AbstractChannelHandlerContext.invokeWrite0(AbstractChannelHandlerContext.java:877)
# 	at io.netty.channel.AbstractChannelHandlerContext.invokeWriteAndFlush(AbstractChannelHandlerContext.java:940)
# 	at io.netty.channel.AbstractChannelHandlerContext$WriteTask.run(AbstractChannelHandlerContext.java:1247)
# 	at io.netty.util.concurrent.AbstractEventExecutor.runTask(AbstractEventExecutor.java:174)
# 	at io.netty.util.concurrent.AbstractEventExecutor.safeExecute(AbstractEventExecutor.java:167)
# 	at io.netty.util.concurrent.SingleThreadEventExecutor.runAllTasks(SingleThreadEventExecutor.java:470)
# 	at io.netty.channel.nio.NioEventLoop.run(NioEventLoop.java:569)
# 	at io.netty.util.concurrent.SingleThreadEventExecutor$4.run(SingleThreadEventExecutor.java:997)
# 	at io.netty.util.internal.ThreadExecutorMap$2.run(ThreadExecutorMap.java:74)
# 	at io.netty.util.concurrent.FastThreadLocalRunnable.run(FastThreadLocalRunnable.java:30)
# 	at java.lang.Thread.run(Thread.java:750)
# Caused by: io.netty.channel.StacklessClosedChannelException
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe.write(Object, ChannelPromise)(Unknown Source)
# 24/03/07 20:37:58 ERROR TransportClient: Failed to send RPC RPC 4769689652533559519 to /192.168.2.142:51656: io.netty.channel.StacklessClosedChannelException
# io.netty.channel.StacklessClosedChannelException
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe.write(Object, ChannelPromise)(Unknown Source)
# 24/03/07 20:37:58 WARN BlockManagerMasterEndpoint: Error trying to remove broadcast 39215 from block manager BlockManagerId(0, 192.168.2.142, 10005, None)
# java.io.IOException: Failed to send RPC RPC 4769689652533559519 to /192.168.2.142:51656: io.netty.channel.StacklessClosedChannelException
# 	at org.apache.spark.network.client.TransportClient$RpcChannelListener.handleFailure(TransportClient.java:395)
# 	at org.apache.spark.network.client.TransportClient$StdChannelListener.operationComplete(TransportClient.java:372)
# 	at io.netty.util.concurrent.DefaultPromise.notifyListener0(DefaultPromise.java:590)
# 	at io.netty.util.concurrent.DefaultPromise.notifyListenersNow(DefaultPromise.java:557)
# 	at io.netty.util.concurrent.DefaultPromise.notifyListeners(DefaultPromise.java:492)
# 	at io.netty.util.concurrent.DefaultPromise.setValue0(DefaultPromise.java:636)
# 	at io.netty.util.concurrent.DefaultPromise.setFailure0(DefaultPromise.java:629)
# 	at io.netty.util.concurrent.DefaultPromise.tryFailure(DefaultPromise.java:118)
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe.safeSetFailure(AbstractChannel.java:999)
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe.write(AbstractChannel.java:860)
# 	at io.netty.channel.DefaultChannelPipeline$HeadContext.write(DefaultChannelPipeline.java:1367)
# 	at io.netty.channel.AbstractChannelHandlerContext.invokeWrite0(AbstractChannelHandlerContext.java:877)
# 	at io.netty.channel.AbstractChannelHandlerContext.invokeWriteAndFlush(AbstractChannelHandlerContext.java:940)
# 	at io.netty.channel.AbstractChannelHandlerContext$WriteTask.run(AbstractChannelHandlerContext.java:1247)
# 	at io.netty.util.concurrent.AbstractEventExecutor.runTask(AbstractEventExecutor.java:174)
# 	at io.netty.util.concurrent.AbstractEventExecutor.safeExecute(AbstractEventExecutor.java:167)
# 	at io.netty.util.concurrent.SingleThreadEventExecutor.runAllTasks(SingleThreadEventExecutor.java:470)
# 	at io.netty.channel.nio.NioEventLoop.run(NioEventLoop.java:569)
# 	at io.netty.util.concurrent.SingleThreadEventExecutor$4.run(SingleThreadEventExecutor.java:997)
# 	at io.netty.util.internal.ThreadExecutorMap$2.run(ThreadExecutorMap.java:74)
# 	at io.netty.util.concurrent.FastThreadLocalRunnable.run(FastThreadLocalRunnable.java:30)
# 	at java.lang.Thread.run(Thread.java:750)
# Caused by: io.netty.channel.StacklessClosedChannelException
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe.write(Object, ChannelPromise)(Unknown Source)
# 24/03/07 20:37:58 ERROR TransportClient: Failed to send RPC RPC 4805777384509845927 to /192.168.2.142:51656: io.netty.channel.StacklessClosedChannelException
# io.netty.channel.StacklessClosedChannelException
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe.write(Object, ChannelPromise)(Unknown Source)
# 24/03/07 20:37:58 WARN BlockManagerMasterEndpoint: Error trying to remove broadcast 38691 from block manager BlockManagerId(0, 192.168.2.142, 10005, None)
# java.io.IOException: Failed to send RPC RPC 4805777384509845927 to /192.168.2.142:51656: io.netty.channel.StacklessClosedChannelException
# 	at org.apache.spark.network.client.TransportClient$RpcChannelListener.handleFailure(TransportClient.java:395)
# 	at org.apache.spark.network.client.TransportClient$StdChannelListener.operationComplete(TransportClient.java:372)
# 	at io.netty.util.concurrent.DefaultPromise.notifyListener0(DefaultPromise.java:590)
# 	at io.netty.util.concurrent.DefaultPromise.notifyListenersNow(DefaultPromise.java:557)
# 	at io.netty.util.concurrent.DefaultPromise.notifyListeners(DefaultPromise.java:492)
# 	at io.netty.util.concurrent.DefaultPromise.setValue0(DefaultPromise.java:636)
# 	at io.netty.util.concurrent.DefaultPromise.setFailure0(DefaultPromise.java:629)
# 	at io.netty.util.concurrent.DefaultPromise.tryFailure(DefaultPromise.java:118)
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe.safeSetFailure(AbstractChannel.java:999)
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe.write(AbstractChannel.java:860)
# 	at io.netty.channel.DefaultChannelPipeline$HeadContext.write(DefaultChannelPipeline.java:1367)
# 	at io.netty.channel.AbstractChannelHandlerContext.invokeWrite0(AbstractChannelHandlerContext.java:877)
# 	at io.netty.channel.AbstractChannelHandlerContext.invokeWriteAndFlush(AbstractChannelHandlerContext.java:940)
# 	at io.netty.channel.AbstractChannelHandlerContext$WriteTask.run(AbstractChannelHandlerContext.java:1247)
# 	at io.netty.util.concurrent.AbstractEventExecutor.runTask(AbstractEventExecutor.java:174)
# 	at io.netty.util.concurrent.AbstractEventExecutor.safeExecute(AbstractEventExecutor.java:167)
# 	at io.netty.util.concurrent.SingleThreadEventExecutor.runAllTasks(SingleThreadEventExecutor.java:470)
# 	at io.netty.channel.nio.NioEventLoop.run(NioEventLoop.java:569)
# 	at io.netty.util.concurrent.SingleThreadEventExecutor$4.run(SingleThreadEventExecutor.java:997)
# 	at io.netty.util.internal.ThreadExecutorMap$2.run(ThreadExecutorMap.java:74)
# 	at io.netty.util.concurrent.FastThreadLocalRunnable.run(FastThreadLocalRunnable.java:30)
# 	at java.lang.Thread.run(Thread.java:750)
# Caused by: io.netty.channel.StacklessClosedChannelException
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe.write(Object, ChannelPromise)(Unknown Source)
# 24/03/07 20:37:58 ERROR TransportClient: Failed to send RPC RPC 7684975120718137040 to /192.168.2.142:51656: io.netty.channel.StacklessClosedChannelException
# io.netty.channel.StacklessClosedChannelException
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe.write(Object, ChannelPromise)(Unknown Source)
# 24/03/07 20:37:58 WARN BlockManagerMasterEndpoint: Error trying to remove broadcast 39905 from block manager BlockManagerId(0, 192.168.2.142, 10005, None)
# java.io.IOException: Failed to send RPC RPC 7684975120718137040 to /192.168.2.142:51656: io.netty.channel.StacklessClosedChannelException
# 	at org.apache.spark.network.client.TransportClient$RpcChannelListener.handleFailure(TransportClient.java:395)
# 	at org.apache.spark.network.client.TransportClient$StdChannelListener.operationComplete(TransportClient.java:372)
# 	at io.netty.util.concurrent.DefaultPromise.notifyListener0(DefaultPromise.java:590)
# 	at io.netty.util.concurrent.DefaultPromise.notifyListenersNow(DefaultPromise.java:557)
# 	at io.netty.util.concurrent.DefaultPromise.notifyListeners(DefaultPromise.java:492)
# 	at io.netty.util.concurrent.DefaultPromise.setValue0(DefaultPromise.java:636)
# 	at io.netty.util.concurrent.DefaultPromise.setFailure0(DefaultPromise.java:629)
# 	at io.netty.util.concurrent.DefaultPromise.tryFailure(DefaultPromise.java:118)
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe.safeSetFailure(AbstractChannel.java:999)
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe.write(AbstractChannel.java:860)
# 	at io.netty.channel.DefaultChannelPipeline$HeadContext.write(DefaultChannelPipeline.java:1367)
# 	at io.netty.channel.AbstractChannelHandlerContext.invokeWrite0(AbstractChannelHandlerContext.java:877)
# 	at io.netty.channel.AbstractChannelHandlerContext.invokeWriteAndFlush(AbstractChannelHandlerContext.java:940)
# 	at io.netty.channel.AbstractChannelHandlerContext$WriteTask.run(AbstractChannelHandlerContext.java:1247)
# 	at io.netty.util.concurrent.AbstractEventExecutor.runTask(AbstractEventExecutor.java:174)
# 	at io.netty.util.concurrent.AbstractEventExecutor.safeExecute(AbstractEventExecutor.java:167)
# 	at io.netty.util.concurrent.SingleThreadEventExecutor.runAllTasks(SingleThreadEventExecutor.java:470)
# 	at io.netty.channel.nio.NioEventLoop.run(NioEventLoop.java:569)
# 	at io.netty.util.concurrent.SingleThreadEventExecutor$4.run(SingleThreadEventExecutor.java:997)
# 	at io.netty.util.internal.ThreadExecutorMap$2.run(ThreadExecutorMap.java:74)
# 	at io.netty.util.concurrent.FastThreadLocalRunnable.run(FastThreadLocalRunnable.java:30)
# 	at java.lang.Thread.run(Thread.java:750)
# Caused by: io.netty.channel.StacklessClosedChannelException
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe.write(Object, ChannelPromise)(Unknown Source)
# 24/03/07 20:37:58 ERROR TransportClient: Failed to send RPC RPC 4666201444089898141 to /192.168.2.142:51656: io.netty.channel.StacklessClosedChannelException
# io.netty.channel.StacklessClosedChannelException
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe.write(Object, ChannelPromise)(Unknown Source)
# 24/03/07 20:37:58 WARN BlockManagerMasterEndpoint: Error trying to remove broadcast 39759 from block manager BlockManagerId(0, 192.168.2.142, 10005, None)
# java.io.IOException: Failed to send RPC RPC 4666201444089898141 to /192.168.2.142:51656: io.netty.channel.StacklessClosedChannelException
# 	at org.apache.spark.network.client.TransportClient$RpcChannelListener.handleFailure(TransportClient.java:395)
# 	at org.apache.spark.network.client.TransportClient$StdChannelListener.operationComplete(TransportClient.java:372)
# 	at io.netty.util.concurrent.DefaultPromise.notifyListener0(DefaultPromise.java:590)
# 	at io.netty.util.concurrent.DefaultPromise.notifyListenersNow(DefaultPromise.java:557)
# 	at io.netty.util.concurrent.DefaultPromise.notifyListeners(DefaultPromise.java:492)
# 	at io.netty.util.concurrent.DefaultPromise.setValue0(DefaultPromise.java:636)
# 	at io.netty.util.concurrent.DefaultPromise.setFailure0(DefaultPromise.java:629)
# 	at io.netty.util.concurrent.DefaultPromise.tryFailure(DefaultPromise.java:118)
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe.safeSetFailure(AbstractChannel.java:999)
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe.write(AbstractChannel.java:860)
# 	at io.netty.channel.DefaultChannelPipeline$HeadContext.write(DefaultChannelPipeline.java:1367)
# 	at io.netty.channel.AbstractChannelHandlerContext.invokeWrite0(AbstractChannelHandlerContext.java:877)
# 	at io.netty.channel.AbstractChannelHandlerContext.invokeWriteAndFlush(AbstractChannelHandlerContext.java:940)
# 	at io.netty.channel.AbstractChannelHandlerContext$WriteTask.run(AbstractChannelHandlerContext.java:1247)
# 	at io.netty.util.concurrent.AbstractEventExecutor.runTask(AbstractEventExecutor.java:174)
# 	at io.netty.util.concurrent.AbstractEventExecutor.safeExecute(AbstractEventExecutor.java:167)
# 	at io.netty.util.concurrent.SingleThreadEventExecutor.runAllTasks(SingleThreadEventExecutor.java:470)
# 	at io.netty.channel.nio.NioEventLoop.run(NioEventLoop.java:569)
# 	at io.netty.util.concurrent.SingleThreadEventExecutor$4.run(SingleThreadEventExecutor.java:997)
# 	at io.netty.util.internal.ThreadExecutorMap$2.run(ThreadExecutorMap.java:74)
# 	at io.netty.util.concurrent.FastThreadLocalRunnable.run(FastThreadLocalRunnable.java:30)
# 	at java.lang.Thread.run(Thread.java:750)
# Caused by: io.netty.channel.StacklessClosedChannelException
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe.write(Object, ChannelPromise)(Unknown Source)
# 24/03/07 20:37:58 ERROR TransportClient: Failed to send RPC RPC 7916532149695259272 to /192.168.2.142:51656: io.netty.channel.StacklessClosedChannelException
# io.netty.channel.StacklessClosedChannelException
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe.write(Object, ChannelPromise)(Unknown Source)
# 24/03/07 20:37:58 WARN BlockManagerMasterEndpoint: Error trying to remove broadcast 38601 from block manager BlockManagerId(0, 192.168.2.142, 10005, None)
# java.io.IOException: Failed to send RPC RPC 7916532149695259272 to /192.168.2.142:51656: io.netty.channel.StacklessClosedChannelException
# 	at org.apache.spark.network.client.TransportClient$RpcChannelListener.handleFailure(TransportClient.java:395)
# 	at org.apache.spark.network.client.TransportClient$StdChannelListener.operationComplete(TransportClient.java:372)
# 	at io.netty.util.concurrent.DefaultPromise.notifyListener0(DefaultPromise.java:590)
# 	at io.netty.util.concurrent.DefaultPromise.notifyListenersNow(DefaultPromise.java:557)
# 	at io.netty.util.concurrent.DefaultPromise.notifyListeners(DefaultPromise.java:492)
# 	at io.netty.util.concurrent.DefaultPromise.setValue0(DefaultPromise.java:636)
# 	at io.netty.util.concurrent.DefaultPromise.setFailure0(DefaultPromise.java:629)
# 	at io.netty.util.concurrent.DefaultPromise.tryFailure(DefaultPromise.java:118)
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe.safeSetFailure(AbstractChannel.java:999)
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe.write(AbstractChannel.java:860)
# 	at io.netty.channel.DefaultChannelPipeline$HeadContext.write(DefaultChannelPipeline.java:1367)
# 	at io.netty.channel.AbstractChannelHandlerContext.invokeWrite0(AbstractChannelHandlerContext.java:877)
# 	at io.netty.channel.AbstractChannelHandlerContext.invokeWriteAndFlush(AbstractChannelHandlerContext.java:940)
# 	at io.netty.channel.AbstractChannelHandlerContext$WriteTask.run(AbstractChannelHandlerContext.java:1247)
# 	at io.netty.util.concurrent.AbstractEventExecutor.runTask(AbstractEventExecutor.java:174)
# 	at io.netty.util.concurrent.AbstractEventExecutor.safeExecute(AbstractEventExecutor.java:167)
# 	at io.netty.util.concurrent.SingleThreadEventExecutor.runAllTasks(SingleThreadEventExecutor.java:470)
# 	at io.netty.channel.nio.NioEventLoop.run(NioEventLoop.java:569)
# 	at io.netty.util.concurrent.SingleThreadEventExecutor$4.run(SingleThreadEventExecutor.java:997)
# 	at io.netty.util.internal.ThreadExecutorMap$2.run(ThreadExecutorMap.java:74)
# 	at io.netty.util.concurrent.FastThreadLocalRunnable.run(FastThreadLocalRunnable.java:30)
# 	at java.lang.Thread.run(Thread.java:750)
# Caused by: io.netty.channel.StacklessClosedChannelException
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe.write(Object, ChannelPromise)(Unknown Source)
# 24/03/07 20:37:58 ERROR TransportClient: Failed to send RPC RPC 7349275299110235527 to /192.168.2.142:51656: io.netty.channel.StacklessClosedChannelException
# io.netty.channel.StacklessClosedChannelException
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe.write(Object, ChannelPromise)(Unknown Source)
# 24/03/07 20:37:58 WARN BlockManagerMasterEndpoint: Error trying to remove broadcast 39833 from block manager BlockManagerId(0, 192.168.2.142, 10005, None)
# java.io.IOException: Failed to send RPC RPC 7349275299110235527 to /192.168.2.142:51656: io.netty.channel.StacklessClosedChannelException
# 	at org.apache.spark.network.client.TransportClient$RpcChannelListener.handleFailure(TransportClient.java:395)
# 	at org.apache.spark.network.client.TransportClient$StdChannelListener.operationComplete(TransportClient.java:372)
# 	at io.netty.util.concurrent.DefaultPromise.notifyListener0(DefaultPromise.java:590)
# 	at io.netty.util.concurrent.DefaultPromise.notifyListenersNow(DefaultPromise.java:557)
# 	at io.netty.util.concurrent.DefaultPromise.notifyListeners(DefaultPromise.java:492)
# 	at io.netty.util.concurrent.DefaultPromise.setValue0(DefaultPromise.java:636)
# 	at io.netty.util.concurrent.DefaultPromise.setFailure0(DefaultPromise.java:629)
# 	at io.netty.util.concurrent.DefaultPromise.tryFailure(DefaultPromise.java:118)
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe.safeSetFailure(AbstractChannel.java:999)
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe.write(AbstractChannel.java:860)
# 	at io.netty.channel.DefaultChannelPipeline$HeadContext.write(DefaultChannelPipeline.java:1367)
# 	at io.netty.channel.AbstractChannelHandlerContext.invokeWrite0(AbstractChannelHandlerContext.java:877)
# 	at io.netty.channel.AbstractChannelHandlerContext.invokeWriteAndFlush(AbstractChannelHandlerContext.java:940)
# 	at io.netty.channel.AbstractChannelHandlerContext$WriteTask.run(AbstractChannelHandlerContext.java:1247)
# 	at io.netty.util.concurrent.AbstractEventExecutor.runTask(AbstractEventExecutor.java:174)
# 	at io.netty.util.concurrent.AbstractEventExecutor.safeExecute(AbstractEventExecutor.java:167)
# 	at io.netty.util.concurrent.SingleThreadEventExecutor.runAllTasks(SingleThreadEventExecutor.java:470)
# 	at io.netty.channel.nio.NioEventLoop.run(NioEventLoop.java:569)
# 	at io.netty.util.concurrent.SingleThreadEventExecutor$4.run(SingleThreadEventExecutor.java:997)
# 	at io.netty.util.internal.ThreadExecutorMap$2.run(ThreadExecutorMap.java:74)
# 	at io.netty.util.concurrent.FastThreadLocalRunnable.run(FastThreadLocalRunnable.java:30)
# 	at java.lang.Thread.run(Thread.java:750)
# Caused by: io.netty.channel.StacklessClosedChannelException
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe.write(Object, ChannelPromise)(Unknown Source)
# 24/03/07 20:37:58 ERROR TransportClient: Failed to send RPC RPC 8358777792513986117 to /192.168.2.142:51656: io.netty.channel.StacklessClosedChannelException
# io.netty.channel.StacklessClosedChannelException
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe.write(Object, ChannelPromise)(Unknown Source)
# 24/03/07 20:37:58 WARN BlockManagerMasterEndpoint: Error trying to remove broadcast 39702 from block manager BlockManagerId(0, 192.168.2.142, 10005, None)
# java.io.IOException: Failed to send RPC RPC 8358777792513986117 to /192.168.2.142:51656: io.netty.channel.StacklessClosedChannelException
# 	at org.apache.spark.network.client.TransportClient$RpcChannelListener.handleFailure(TransportClient.java:395)
# 	at org.apache.spark.network.client.TransportClient$StdChannelListener.operationComplete(TransportClient.java:372)
# 	at io.netty.util.concurrent.DefaultPromise.notifyListener0(DefaultPromise.java:590)
# 	at io.netty.util.concurrent.DefaultPromise.notifyListenersNow(DefaultPromise.java:557)
# 	at io.netty.util.concurrent.DefaultPromise.notifyListeners(DefaultPromise.java:492)
# 	at io.netty.util.concurrent.DefaultPromise.setValue0(DefaultPromise.java:636)
# 	at io.netty.util.concurrent.DefaultPromise.setFailure0(DefaultPromise.java:629)
# 	at io.netty.util.concurrent.DefaultPromise.tryFailure(DefaultPromise.java:118)
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe.safeSetFailure(AbstractChannel.java:999)
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe.write(AbstractChannel.java:860)
# 	at io.netty.channel.DefaultChannelPipeline$HeadContext.write(DefaultChannelPipeline.java:1367)
# 	at io.netty.channel.AbstractChannelHandlerContext.invokeWrite0(AbstractChannelHandlerContext.java:877)
# 	at io.netty.channel.AbstractChannelHandlerContext.invokeWriteAndFlush(AbstractChannelHandlerContext.java:940)
# 	at io.netty.channel.AbstractChannelHandlerContext$WriteTask.run(AbstractChannelHandlerContext.java:1247)
# 	at io.netty.util.concurrent.AbstractEventExecutor.runTask(AbstractEventExecutor.java:174)
# 	at io.netty.util.concurrent.AbstractEventExecutor.safeExecute(AbstractEventExecutor.java:167)
# 	at io.netty.util.concurrent.SingleThreadEventExecutor.runAllTasks(SingleThreadEventExecutor.java:470)
# 	at io.netty.channel.nio.NioEventLoop.run(NioEventLoop.java:569)
# 	at io.netty.util.concurrent.SingleThreadEventExecutor$4.run(SingleThreadEventExecutor.java:997)
# 	at io.netty.util.internal.ThreadExecutorMap$2.run(ThreadExecutorMap.java:74)
# 	at io.netty.util.concurrent.FastThreadLocalRunnable.run(FastThreadLocalRunnable.java:30)
# 	at java.lang.Thread.run(Thread.java:750)
# Caused by: io.netty.channel.StacklessClosedChannelException
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe.write(Object, ChannelPromise)(Unknown Source)
# 24/03/07 20:37:58 ERROR TransportClient: Failed to send RPC RPC 4718551477055081782 to /192.168.2.142:51656: io.netty.channel.StacklessClosedChannelException
# io.netty.channel.StacklessClosedChannelException
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe.write(Object, ChannelPromise)(Unknown Source)
# 24/03/07 20:37:58 WARN BlockManagerMasterEndpoint: Error trying to remove broadcast 38859 from block manager BlockManagerId(0, 192.168.2.142, 10005, None)
# java.io.IOException: Failed to send RPC RPC 4718551477055081782 to /192.168.2.142:51656: io.netty.channel.StacklessClosedChannelException
# 	at org.apache.spark.network.client.TransportClient$RpcChannelListener.handleFailure(TransportClient.java:395)
# 	at org.apache.spark.network.client.TransportClient$StdChannelListener.operationComplete(TransportClient.java:372)
# 	at io.netty.util.concurrent.DefaultPromise.notifyListener0(DefaultPromise.java:590)
# 	at io.netty.util.concurrent.DefaultPromise.notifyListenersNow(DefaultPromise.java:557)
# 	at io.netty.util.concurrent.DefaultPromise.notifyListeners(DefaultPromise.java:492)
# 	at io.netty.util.concurrent.DefaultPromise.setValue0(DefaultPromise.java:636)
# 	at io.netty.util.concurrent.DefaultPromise.setFailure0(DefaultPromise.java:629)
# 	at io.netty.util.concurrent.DefaultPromise.tryFailure(DefaultPromise.java:118)
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe.safeSetFailure(AbstractChannel.java:999)
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe.write(AbstractChannel.java:860)
# 	at io.netty.channel.DefaultChannelPipeline$HeadContext.write(DefaultChannelPipeline.java:1367)
# 	at io.netty.channel.AbstractChannelHandlerContext.invokeWrite0(AbstractChannelHandlerContext.java:877)
# 	at io.netty.channel.AbstractChannelHandlerContext.invokeWriteAndFlush(AbstractChannelHandlerContext.java:940)
# 	at io.netty.channel.AbstractChannelHandlerContext$WriteTask.run(AbstractChannelHandlerContext.java:1247)
# 	at io.netty.util.concurrent.AbstractEventExecutor.runTask(AbstractEventExecutor.java:174)
# 	at io.netty.util.concurrent.AbstractEventExecutor.safeExecute(AbstractEventExecutor.java:167)
# 	at io.netty.util.concurrent.SingleThreadEventExecutor.runAllTasks(SingleThreadEventExecutor.java:470)
# 	at io.netty.channel.nio.NioEventLoop.run(NioEventLoop.java:569)
# 	at io.netty.util.concurrent.SingleThreadEventExecutor$4.run(SingleThreadEventExecutor.java:997)
# 	at io.netty.util.internal.ThreadExecutorMap$2.run(ThreadExecutorMap.java:74)
# 	at io.netty.util.concurrent.FastThreadLocalRunnable.run(FastThreadLocalRunnable.java:30)
# 	at java.lang.Thread.run(Thread.java:750)
# Caused by: io.netty.channel.StacklessClosedChannelException
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe.write(Object, ChannelPromise)(Unknown Source)
# 24/03/07 20:37:58 ERROR TransportClient: Failed to send RPC RPC 5413182200587314869 to /192.168.2.142:51656: io.netty.channel.StacklessClosedChannelException
# io.netty.channel.StacklessClosedChannelException
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe.write(Object, ChannelPromise)(Unknown Source)
# 24/03/07 20:37:58 WARN BlockManagerMasterEndpoint: Error trying to remove broadcast 39709 from block manager BlockManagerId(0, 192.168.2.142, 10005, None)
# java.io.IOException: Failed to send RPC RPC 5413182200587314869 to /192.168.2.142:51656: io.netty.channel.StacklessClosedChannelException
# 	at org.apache.spark.network.client.TransportClient$RpcChannelListener.handleFailure(TransportClient.java:395)
# 	at org.apache.spark.network.client.TransportClient$StdChannelListener.operationComplete(TransportClient.java:372)
# 	at io.netty.util.concurrent.DefaultPromise.notifyListener0(DefaultPromise.java:590)
# 	at io.netty.util.concurrent.DefaultPromise.notifyListenersNow(DefaultPromise.java:557)
# 	at io.netty.util.concurrent.DefaultPromise.notifyListeners(DefaultPromise.java:492)
# 	at io.netty.util.concurrent.DefaultPromise.setValue0(DefaultPromise.java:636)
# 	at io.netty.util.concurrent.DefaultPromise.setFailure0(DefaultPromise.java:629)
# 	at io.netty.util.concurrent.DefaultPromise.tryFailure(DefaultPromise.java:118)
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe.safeSetFailure(AbstractChannel.java:999)
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe.write(AbstractChannel.java:860)
# 	at io.netty.channel.DefaultChannelPipeline$HeadContext.write(DefaultChannelPipeline.java:1367)
# 	at io.netty.channel.AbstractChannelHandlerContext.invokeWrite0(AbstractChannelHandlerContext.java:877)
# 	at io.netty.channel.AbstractChannelHandlerContext.invokeWriteAndFlush(AbstractChannelHandlerContext.java:940)
# 	at io.netty.channel.AbstractChannelHandlerContext$WriteTask.run(AbstractChannelHandlerContext.java:1247)
# 	at io.netty.util.concurrent.AbstractEventExecutor.runTask(AbstractEventExecutor.java:174)
# 	at io.netty.util.concurrent.AbstractEventExecutor.safeExecute(AbstractEventExecutor.java:167)
# 	at io.netty.util.concurrent.SingleThreadEventExecutor.runAllTasks(SingleThreadEventExecutor.java:470)
# 	at io.netty.channel.nio.NioEventLoop.run(NioEventLoop.java:569)
# 	at io.netty.util.concurrent.SingleThreadEventExecutor$4.run(SingleThreadEventExecutor.java:997)
# 	at io.netty.util.internal.ThreadExecutorMap$2.run(ThreadExecutorMap.java:74)
# 	at io.netty.util.concurrent.FastThreadLocalRunnable.run(FastThreadLocalRunnable.java:30)
# 	at java.lang.Thread.run(Thread.java:750)
# Caused by: io.netty.channel.StacklessClosedChannelException
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe.write(Object, ChannelPromise)(Unknown Source)
# 24/03/07 20:37:58 ERROR TransportClient: Failed to send RPC RPC 5868218970121078685 to /192.168.2.142:51656: io.netty.channel.StacklessClosedChannelException
# io.netty.channel.StacklessClosedChannelException
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe.write(Object, ChannelPromise)(Unknown Source)
# 24/03/07 20:37:58 WARN BlockManagerMasterEndpoint: Error trying to remove broadcast 39413 from block manager BlockManagerId(0, 192.168.2.142, 10005, None)
# java.io.IOException: Failed to send RPC RPC 5868218970121078685 to /192.168.2.142:51656: io.netty.channel.StacklessClosedChannelException
# 	at org.apache.spark.network.client.TransportClient$RpcChannelListener.handleFailure(TransportClient.java:395)
# 	at org.apache.spark.network.client.TransportClient$StdChannelListener.operationComplete(TransportClient.java:372)
# 	at io.netty.util.concurrent.DefaultPromise.notifyListener0(DefaultPromise.java:590)
# 	at io.netty.util.concurrent.DefaultPromise.notifyListenersNow(DefaultPromise.java:557)
# 	at io.netty.util.concurrent.DefaultPromise.notifyListeners(DefaultPromise.java:492)
# 	at io.netty.util.concurrent.DefaultPromise.setValue0(DefaultPromise.java:636)
# 	at io.netty.util.concurrent.DefaultPromise.setFailure0(DefaultPromise.java:629)
# 	at io.netty.util.concurrent.DefaultPromise.tryFailure(DefaultPromise.java:118)
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe.safeSetFailure(AbstractChannel.java:999)
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe.write(AbstractChannel.java:860)
# 	at io.netty.channel.DefaultChannelPipeline$HeadContext.write(DefaultChannelPipeline.java:1367)
# 	at io.netty.channel.AbstractChannelHandlerContext.invokeWrite0(AbstractChannelHandlerContext.java:877)
# 	at io.netty.channel.AbstractChannelHandlerContext.invokeWriteAndFlush(AbstractChannelHandlerContext.java:940)
# ...
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39213_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39335_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39329_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_38641_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39431_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39935_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39125_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39625_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39045_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_38863_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_38831_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_38975_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39241_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39111_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39773_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_38701_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_38909_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39631_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_38809_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39495_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_38717_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_38713_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_38989_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39731_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39695_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39777_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39317_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39807_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_38725_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39725_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39067_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39643_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_38919_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39227_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39421_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_38695_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39417_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_38895_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39577_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39511_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39743_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39437_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39781_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39817_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39829_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_38691_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39155_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39653_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39159_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39085_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_38859_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_38621_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39825_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39095_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39463_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39911_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39137_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39549_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_38579_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39449_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39099_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39043_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39739_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_38659_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39109_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_38745_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39637_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39641_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39079_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39581_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_38603_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39599_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39239_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39713_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39839_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39021_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_38857_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39563_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39947_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_38835_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39047_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39505_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39833_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_38737_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_38995_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_38721_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_38935_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_38751_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39543_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_38647_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39003_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39357_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39827_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39413_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39135_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39753_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_38765_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_38769_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_38945_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39411_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39805_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39517_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_38581_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39429_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39279_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39219_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39485_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39069_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39623_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39983_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39087_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39613_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39835_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_38685_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39819_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39065_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_38867_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39339_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39961_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39491_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_38705_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39765_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39917_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39209_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39225_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39443_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39793_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39593_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39399_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_38557_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39245_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39013_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_38591_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39101_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39331_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39075_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_38851_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39575_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_38555_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39815_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39553_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39953_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_38985_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39035_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_38993_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_38729_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_38911_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_38937_piece0 !
# 24/03/07 20:38:03 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_39061_piece0 !

# %%
# Read DataFrame from csv file in HDFS to verify
df = spark_session.read.csv("hdfs://192.168.2.130:9000/user/MillionSongSubset.csv")
df.show()
df.printSchema()
print(df.count())
print(df.rdd.getNumPartitions())
# Out:
# +--------------------+---+---------+-----+---+---+-----+-------+---+-----+--------------------+-------------------+------------------+-------+-------+----+-----+--------------------+----+
# |                 _c0|_c1|      _c2|  _c3|_c4|_c5|  _c6|    _c7|_c8|  _c9|                _c10|               _c11|              _c12|   _c13|   _c14|_c15| _c16|                _c17|_c18|
# +--------------------+---+---------+-----+---+---+-----+-------+---+-----+--------------------+-------------------+------------------+-------+-------+----+-----+--------------------+----+
# |              Casual|0.0|218.93179|0.247|0.0|  1|0.736|-11.197|  0|0.636|         Fear Itself| 0.6021199899057548|SOMZWCG12A8C13C480|218.932| 92.198|   4|0.778|    I Didn't Mean To|   0|
# |        The Box Tops|0.0|148.03546|0.148|0.0|  6|0.169| -9.843|  0| 0.43|          Dimensions|                NaN|SOCIWDW12A8C13D406|137.915|121.274|   4|0.384|           Soul Deep|1969|
# |    Sonora Santanera|0.0|177.47546|0.282|0.0|  8|0.643| -9.689|  1|0.565|Las Numero 1 De L...|                NaN|SOXVLOJ12AB0189215|172.304| 100.07|   1|  0.0|     Amor De Cabaret|   0|
# |            Adam Ant|0.0|233.40363|  0.0|0.0|  0|0.751| -9.013|  1|0.749|       Friend Or Foe|                NaN|SONHOTT12A8C13493C|217.124|119.293|   4|  0.0|     Something Girls|1982|
# |                 Gob|0.0|209.60608|0.066|0.0|  2|0.092| -4.501|  1|0.371|       Muertos Vivos| 0.6045007385888197|SOFSOCN12A8C143F5D|198.699|129.738|   4|0.562|      Face the Ashes|2007|
# |Jeff And Sheri Ea...|0.0| 267.7024|2.264|0.0|  5|0.635| -9.323|  1|0.557|        Ordinary Day|                NaN|SOYMRWW12A6D4FAB14| 254.27|147.782|   3|0.454|The Moon And I (O...|   0|
# |             Rated R|0.0|114.78159|0.096|0.0|  1|  0.0|-17.302|  1|  0.0|   Da Ghetto Psychic|                NaN|SOMJBYD12A6D4F8557|114.782|111.787|   1|  0.0|Keepin It Real (S...|   0|
# |Tweeterfriendly M...|0.0|189.57016|0.319|0.0|  4|  0.0|-11.642|  0| 0.16|        Gin & Phonic|                NaN|SOHKNRJ12A6701D1F8|181.023| 101.43|   3|0.408|        Drop of Rain|   0|
# |    Planet P Project|0.0|269.81832|  5.3|0.0|  4|0.717|-13.496|  1|0.652|          Pink World|0.26586104921065007|SOIAZJW12AB01853F1| 258.99| 86.643|   4|0.487|          Pink World|1984|
# |                 Clp|0.0|266.39628|0.084|0.0|  7|0.053| -6.697|  0|0.473|   Superinstrumental|                NaN|SOUDSGM12AC9618304|261.747|114.041|   4|0.878|Insatiable (Instr...|   0|
# |        JennyAnyKind|0.0|218.77506|2.125|0.0|  5|0.354|-10.021|  0|0.485|          I Need You|                0.0|SOQHXMF12AB0182363|207.012|146.765|   1|  0.0|     Young Boy Blues|   0|
# |        Wayne Watson|0.0|245.21098|0.357|0.0|  7| 0.07| -7.545|  1|0.686|        The Way Home|0.26586104921065007|SOKEJEJ12A8C13E0D0| 227.48|117.975|   4|0.835|The Urgency (LP V...|   0|
# |           Andy Andy|0.0|226.35057|  0.0|0.0|  9|0.205| -6.632|  1|0.305|    Placer & Castigo|                0.0|SOMUYGI12AB0188633|221.553| 130.04|   4|  0.0|            La Culpa|   0|
# |           Bob Azzam|0.0|191.84281| 0.38|0.0| 10|  0.0|  -7.75|  0|0.198|         Arrivederci|                0.0|SORAMLE12AB017C8B0|188.424|137.334|   1|0.319|      Auguri Cha Cha|   0|
# |       Lionel Richie|0.0| 307.3824|0.612|0.0|  3|0.524| -8.346|  1|0.533|Dancing On The Ce...|                NaN|SOBONFF12A6D4F84D8|296.658|125.197|   3|0.211|Tonight Will Be A...|1986|
# |          Blue Rodeo|0.0|491.12771|  0.0|0.0|  7|  1.0| -8.576|  1|0.829|           Outskirts| 0.4051157216913865|SOHUOAP12A8AE488E9|486.034|119.826|   4|0.756|            Floating|1987|
# |     Richard Souther|0.0| 228.5971|0.223|0.0|  8|0.041| -16.11|  1|0.516|      Cross Currents| 0.3347065490692206|SOUQQEA12A8C134B1B|217.426|127.756|   5|0.579|           High Tide|   0|
# |       Faiz Ali Faiz|0.0|599.24853|1.193|0.0|  6| 0.06| -8.032|  1|0.346|   Panjtan Ka Ghulam|                NaN|SOILPQQ12AB017E82A|591.999| 99.273|   4|0.158|Sohna Nee Sohna Data|   0|
# |               Tesla|0.0|290.29832|0.145|0.0|  7|0.725| -5.271|  1|0.756|                Gold| 0.6841361912294903|SOXLBJT12A8C140925|285.605|150.062|   4|0.931|   Caught In A Dream|2004|
# |           lextrical|0.0|165.69424|0.162|0.0|  7|0.011| -6.787|  1|0.568|Whatever Happened...|                0.0|SOZVMJI12AB01808AF|157.391|138.331|   4|0.127|     Synthetic Dream|   0|
# +--------------------+---+---------+-----+---+---+-----+-------+---+-----+--------------------+-------------------+------------------+-------+-------+----+-----+--------------------+----+
# only showing top 20 rows
#
# root
#  |-- _c0: string (nullable = true)
#  |-- _c1: string (nullable = true)
#  |-- _c2: string (nullable = true)
#  |-- _c3: string (nullable = true)
#  |-- _c4: string (nullable = true)
#  |-- _c5: string (nullable = true)
#  |-- _c6: string (nullable = true)
#  |-- _c7: string (nullable = true)
#  |-- _c8: string (nullable = true)
#  |-- _c9: string (nullable = true)
#  |-- _c10: string (nullable = true)
#  |-- _c11: string (nullable = true)
#  |-- _c12: string (nullable = true)
#  |-- _c13: string (nullable = true)
#  |-- _c14: string (nullable = true)
#  |-- _c15: string (nullable = true)
#  |-- _c16: string (nullable = true)
#  |-- _c17: string (nullable = true)
#  |-- _c18: string (nullable = true)
#
# 10000
# 2

# %%
spark_session.stop()
